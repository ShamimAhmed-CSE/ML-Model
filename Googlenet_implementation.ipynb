# %%
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import AveragePooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model
from keras.layers import concatenate
import matplotlib
matplotlib.use("Agg")
# %matplotlib inline
from sklearn.preprocessing import LabelBinarizer
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD
from keras.datasets import cifar10
import numpy as np

# %%
def conv_module(input,No_of_filters,filtersizeX,filtersizeY,stride,chanDim,padding="same"):
  input = Conv2D(No_of_filters,(filtersizeX,filtersizeY),strides=stride,padding=padding)(input)
  input = BatchNormalization(axis=chanDim)(input)
  input = Activation("relu")(input)
  return input

# %%
def inception_module(input,numK1x1,numK3x3,numk5x5,numPoolProj,chanDim):
                                 #Step 1
  conv_1x1 = conv_module(input, numK1x1, 1, 1,(1, 1), chanDim) 
                                 #Step 2
  conv_3x1 = conv_module(input, numK3x3, 3, 1,(1, 1), chanDim)
  conv_1x3 = conv_module(input, numK3x3, 1, 3,(1, 1), chanDim)
  conv_1x5 = conv_module(input, numk5x5, 1, 5,(1, 1), chanDim)
  conv_5x1 = conv_module(input, numk5x5, 5, 1,(1, 1), chanDim)
                                 #Step 3
  pool_proj = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(input)
  pool_proj = Conv2D(numPoolProj, (1, 1), padding='same', activation='relu')(pool_proj)
                                 #Step 4
  input = concatenate([conv_1x1, conv_3x1,conv_1x3, conv_1x5,conv_5x1, pool_proj], axis=chanDim)
  return input

# %%
def downsample_module(input,No_of_filters,chanDim):
  conv_3x3=conv_module(input,No_of_filters,3,3,(2,2),chanDim,padding="valid")
  pool = MaxPooling2D((3,3),strides=(2,2))(input)
  input = concatenate([conv_3x3,pool],axis=chanDim)
  return input

# %%
def MiniGoogleNet(width,height,depth,classes):
  inputShape=(height,width,depth)
  chanDim=-1

  # (Step 1) Define the model input
  inputs = Input(shape=inputShape)

  # First CONV module
  x = conv_module(inputs, 96, 3, 3, (1, 1),chanDim)

  # (Step 2) Two Inception modules followed by a downsample module
  x = inception_module(x, 32, 32,32,32,chanDim)
  x = inception_module(x, 32, 48, 48,32,chanDim)
  x = downsample_module(x, 80, chanDim)
  
  # (Step 3) Five Inception modules followed by a downsample module
  x = inception_module(x, 112, 48, 32, 48,chanDim)
  x = inception_module(x, 96, 64, 32,32,chanDim)
  x = inception_module(x, 80, 80, 32,32,chanDim)
  x = inception_module(x, 48, 96, 32,32,chanDim)
  x = inception_module(x, 112, 48, 32, 48,chanDim)
  x = downsample_module(x, 96, chanDim)

  # (Step 4) Two Inception modules followed
  x = inception_module(x, 176, 160,96,96, chanDim)
  x = inception_module(x, 176, 160, 96,96,chanDim)
  
  # Global POOL and dropout
  x = AveragePooling2D((7, 7))(x)
  x = Dropout(0.5)(x)

  # (Step 5) Softmax classifier
  x = Flatten()(x)
  x = Dense(classes)(x)
  x = Activation("softmax")(x)

  # Create the model
  model = Model(inputs, x, name="googlenet")
  return model

# %%
NUM_EPOCHS = 10
INIT_LR = 5e-3
def poly_decay(epoch):
  maxEpochs = NUM_EPOCHS
  baseLR = INIT_LR
  power = 1.0
  alpha = baseLR * (1 - (epoch / float(maxEpochs))) ** power
  return alpha

# %%
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float")
testX = testX.astype("float")
                                # Step 1
mean = np.mean(trainX, axis=0)
trainX -= mean
testX -= mean
                                # Step 2
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
                                # Step 3
aug = ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1, horizontal_flip=True,fill_mode="nearest")

# %%
callbacks=[LearningRateScheduler(poly_decay)]
opt = SGD(lr=INIT_LR, momentum=0.9)
model = MiniGoogleNet(width=32, height=32, depth=3, classes=10)
                                    # Step 1
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
                                    # Step 2
model.fit(aug.flow(trainX, trainY, batch_size=64),validation_data=(testX, testY), steps_per_epoch=len(trainX) // 64,epochs=NUM_EPOCHS, callbacks=callbacks, verbose=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/10
# 781/781 [==============================] - 194s 237ms/step - loss: 1.4318 - accuracy: 0.4811 - val_loss: 1.2894 - val_accuracy: 0.5339 - lr: 0.0050
# Epoch 2/10
# 781/781 [==============================] - 180s 230ms/step - loss: 0.9983 - accuracy: 0.6472 - val_loss: 1.1988 - val_accuracy: 0.6172 - lr: 0.0045
# Epoch 3/10
# 781/781 [==============================] - 182s 233ms/step - loss: 0.8121 - accuracy: 0.7132 - val_loss: 0.8935 - val_accuracy: 0.7080 - lr: 0.0040
# Epoch 4/10
# 781/781 [==============================] - 182s 233ms/step - loss: 0.6954 - accuracy: 0.7573 - val_loss: 0.7428 - val_accuracy: 0.7451 - lr: 0.0035
# Epoch 5/10
# 781/781 [==============================] - 182s 232ms/step - loss: 0.6129 - accuracy: 0.7894 - val_loss: 0.8053 - val_accuracy: 0.7323 - lr: 0.0030
# Epoch 6/10
# 781/781 [==============================] - 180s 230ms/step - loss: 0.5546 - accuracy: 0.8087 - val_loss: 0.6857 - val_accuracy: 0.7734 - lr: 0.0025
# Epoch 7/10
# 781/781 [==============================] - 180s 230ms/step - loss: 0.4996 - accuracy: 0.8267 - val_loss: 0.5283 - val_accuracy: 0.8229 - lr: 0.0020
# Epoch 8/10
# 781/781 [==============================] - 181s 232ms/step - loss: 0.4544 - accuracy: 0.8426 - val_loss: 0.5910 - val_accuracy: 0.8037 - lr: 0.0015
# Epoch 9/10
# 781/781 [==============================] - 180s 230ms/step - loss: 0.4157 - accuracy: 0.8561 - val_loss: 0.6239 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 10/10
# 781/781 [==============================] - 181s 232ms/step - loss: 0.3854 - accuracy: 0.8689 - val_loss: 0.4556 - val_accuracy: 0.8480 - lr: 5.0000e-04

# %%
model.summary()
# Out:
# Model: "googlenet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 96)   2688        ['input_3[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 96)  384         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 32)   3104        ['activation_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_42[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_42[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 32)   15392       ['activation_42[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 32)   15392       ['activation_42[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 32)  128         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 32)  128         ['conv2d_55[0][0]']
#  ormalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 96)  0           ['activation_42[0][0]']
#  )
#
#  activation_43 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_45 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_46 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_45[0][0]']
#
#  activation_47 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 32)   3104        ['max_pooling2d_11[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 32, 32, 192)  0           ['activation_43[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_45[0][0]',
#                                                                   'activation_46[0][0]',
#                                                                   'activation_47[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 32)   6176        ['concatenate_11[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 32, 32, 48)   27696       ['concatenate_11[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 32, 32, 48)   27696       ['concatenate_11[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 32, 32, 48)   46128       ['concatenate_11[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 32, 32, 48)   46128       ['concatenate_11[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 32)  128         ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 48)  192         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 48)  192         ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 48)  192         ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 48)  192         ['conv2d_61[0][0]']
#  ormalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 32, 32, 192)  0          ['concatenate_11[0][0]']
#  )
#
#  activation_48 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_47[0][0]']
#
#  activation_49 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_49[0][0]']
#
#  activation_51 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_50[0][0]']
#
#  activation_52 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 32, 32, 32)   6176        ['max_pooling2d_12[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 256)  0           ['activation_48[0][0]',
#                                                                   'activation_49[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_51[0][0]',
#                                                                   'activation_52[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 15, 15, 80)   184400      ['concatenate_12[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 15, 15, 80)  320         ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 15, 15, 80)   0           ['batch_normalization_52[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 15, 15, 256)  0          ['concatenate_12[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 15, 15, 336)  0           ['activation_53[0][0]',
#                                                                   'max_pooling2d_13[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 15, 15, 112)  37744       ['concatenate_13[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 15, 15, 48)   48432       ['concatenate_13[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 15, 15, 48)   48432       ['concatenate_13[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_13[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_13[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 15, 15, 112)  448        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 15, 15, 48)  192         ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 15, 15, 48)  192         ['conv2d_66[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 15, 15, 32)  128         ['conv2d_67[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 15, 15, 32)  128         ['conv2d_68[0][0]']
#  ormalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 15, 15, 336)  0          ['concatenate_13[0][0]']
#  )
#
#  activation_54 (Activation)     (None, 15, 15, 112)  0           ['batch_normalization_53[0][0]']
#
#  activation_55 (Activation)     (None, 15, 15, 48)   0           ['batch_normalization_54[0][0]']
#
#  activation_56 (Activation)     (None, 15, 15, 48)   0           ['batch_normalization_55[0][0]']
#
#  activation_57 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_56[0][0]']
#
#  activation_58 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 15, 15, 48)   16176       ['max_pooling2d_14[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 15, 15, 320)  0           ['activation_54[0][0]',
#                                                                   'activation_55[0][0]',
#                                                                   'activation_56[0][0]',
#                                                                   'activation_57[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 15, 15, 96)   30816       ['concatenate_14[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 15, 15, 64)   61504       ['concatenate_14[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 15, 15, 64)   61504       ['concatenate_14[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 15, 15, 32)   51232       ['concatenate_14[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 15, 15, 32)   51232       ['concatenate_14[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 15, 15, 96)  384         ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 15, 15, 64)  256         ['conv2d_71[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 15, 15, 64)  256         ['conv2d_72[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 15, 15, 32)  128         ['conv2d_73[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 15, 15, 32)  128         ['conv2d_74[0][0]']
#  ormalization)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 15, 15, 320)  0          ['concatenate_14[0][0]']
#  )
#
#  activation_59 (Activation)     (None, 15, 15, 96)   0           ['batch_normalization_58[0][0]']
#
#  activation_60 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_59[0][0]']
#
#  activation_61 (Activation)     (None, 15, 15, 64)   0           ['batch_normalization_60[0][0]']
#
#  activation_62 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_61[0][0]']
#
#  activation_63 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_62[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 15, 15, 32)   10272       ['max_pooling2d_15[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 15, 15, 320)  0           ['activation_59[0][0]',
#                                                                   'activation_60[0][0]',
#                                                                   'activation_61[0][0]',
#                                                                   'activation_62[0][0]',
#                                                                   'activation_63[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 15, 15, 80)   25680       ['concatenate_15[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 15, 15, 80)   76880       ['concatenate_15[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 15, 15, 80)   76880       ['concatenate_15[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 15, 15, 32)   51232       ['concatenate_15[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 15, 15, 32)   51232       ['concatenate_15[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 15, 15, 80)  320         ['conv2d_76[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 15, 15, 80)  320         ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 15, 15, 80)  320         ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 15, 15, 32)  128         ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 15, 15, 32)  128         ['conv2d_80[0][0]']
#  ormalization)
#
#  max_pooling2d_16 (MaxPooling2D  (None, 15, 15, 320)  0          ['concatenate_15[0][0]']
#  )
#
#  activation_64 (Activation)     (None, 15, 15, 80)   0           ['batch_normalization_63[0][0]']
#
#  activation_65 (Activation)     (None, 15, 15, 80)   0           ['batch_normalization_64[0][0]']
#
#  activation_66 (Activation)     (None, 15, 15, 80)   0           ['batch_normalization_65[0][0]']
#
#  activation_67 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_66[0][0]']
#
#  activation_68 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_67[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 15, 15, 32)   10272       ['max_pooling2d_16[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 15, 15, 336)  0           ['activation_64[0][0]',
#                                                                   'activation_65[0][0]',
#                                                                   'activation_66[0][0]',
#                                                                   'activation_67[0][0]',
#                                                                   'activation_68[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 15, 15, 48)   16176       ['concatenate_16[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 15, 15, 96)   96864       ['concatenate_16[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 15, 15, 96)   96864       ['concatenate_16[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_16[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_16[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 15, 15, 48)  192         ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 15, 15, 96)  384         ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 15, 15, 96)  384         ['conv2d_84[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 15, 15, 32)  128         ['conv2d_85[0][0]']
#  ormalization)
#
#  batch_normalization_72 (BatchN  (None, 15, 15, 32)  128         ['conv2d_86[0][0]']
#  ormalization)
#
#  max_pooling2d_17 (MaxPooling2D  (None, 15, 15, 336)  0          ['concatenate_16[0][0]']
#  )
#
#  activation_69 (Activation)     (None, 15, 15, 48)   0           ['batch_normalization_68[0][0]']
#
#  activation_70 (Activation)     (None, 15, 15, 96)   0           ['batch_normalization_69[0][0]']
#
#  activation_71 (Activation)     (None, 15, 15, 96)   0           ['batch_normalization_70[0][0]']
#
#  activation_72 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_71[0][0]']
#
#  activation_73 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_72[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 15, 15, 32)   10784       ['max_pooling2d_17[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 15, 15, 336)  0           ['activation_69[0][0]',
#                                                                   'activation_70[0][0]',
#                                                                   'activation_71[0][0]',
#                                                                   'activation_72[0][0]',
#                                                                   'activation_73[0][0]',
#                                                                   'conv2d_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 15, 15, 112)  37744       ['concatenate_17[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 15, 15, 48)   48432       ['concatenate_17[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 15, 15, 48)   48432       ['concatenate_17[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_17[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 15, 15, 32)   53792       ['concatenate_17[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 15, 15, 112)  448        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_74 (BatchN  (None, 15, 15, 48)  192         ['conv2d_89[0][0]']
#  ormalization)
#
#  batch_normalization_75 (BatchN  (None, 15, 15, 48)  192         ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_76 (BatchN  (None, 15, 15, 32)  128         ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 15, 15, 32)  128         ['conv2d_92[0][0]']
#  ormalization)
#
#  max_pooling2d_18 (MaxPooling2D  (None, 15, 15, 336)  0          ['concatenate_17[0][0]']
#  )
#
#  activation_74 (Activation)     (None, 15, 15, 112)  0           ['batch_normalization_73[0][0]']
#
#  activation_75 (Activation)     (None, 15, 15, 48)   0           ['batch_normalization_74[0][0]']
#
#  activation_76 (Activation)     (None, 15, 15, 48)   0           ['batch_normalization_75[0][0]']
#
#  activation_77 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_76[0][0]']
#
#  activation_78 (Activation)     (None, 15, 15, 32)   0           ['batch_normalization_77[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 15, 15, 48)   16176       ['max_pooling2d_18[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 15, 15, 320)  0           ['activation_74[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'activation_76[0][0]',
#                                                                   'activation_77[0][0]',
#                                                                   'activation_78[0][0]',
#                                                                   'conv2d_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 7, 7, 96)     276576      ['concatenate_18[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 7, 7, 96)    384         ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_78[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 7, 7, 320)   0           ['concatenate_18[0][0]']
#  )
#
#  concatenate_19 (Concatenate)   (None, 7, 7, 416)    0           ['activation_79[0][0]',
#                                                                   'max_pooling2d_19[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 7, 7, 176)    73392       ['concatenate_19[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 7, 7, 160)    199840      ['concatenate_19[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 160)    199840      ['concatenate_19[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 96)     199776      ['concatenate_19[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 7, 7, 96)     199776      ['concatenate_19[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 7, 7, 176)   704         ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_80 (BatchN  (None, 7, 7, 160)   640         ['conv2d_96[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 7, 7, 160)   640         ['conv2d_97[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 7, 7, 96)    384         ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 7, 7, 96)    384         ['conv2d_99[0][0]']
#  ormalization)
#
#  max_pooling2d_20 (MaxPooling2D  (None, 7, 7, 416)   0           ['concatenate_19[0][0]']
#  )
#
#  activation_80 (Activation)     (None, 7, 7, 176)    0           ['batch_normalization_79[0][0]']
#
#  activation_81 (Activation)     (None, 7, 7, 160)    0           ['batch_normalization_80[0][0]']
#
#  activation_82 (Activation)     (None, 7, 7, 160)    0           ['batch_normalization_81[0][0]']
#
#  activation_83 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_82[0][0]']
#
#  activation_84 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_83[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 7, 7, 96)     40032       ['max_pooling2d_20[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 7, 7, 784)    0           ['activation_80[0][0]',
#                                                                   'activation_81[0][0]',
#                                                                   'activation_82[0][0]',
#                                                                   'activation_83[0][0]',
#                                                                   'activation_84[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 176)    138160      ['concatenate_20[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 160)    376480      ['concatenate_20[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 160)    376480      ['concatenate_20[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 96)     376416      ['concatenate_20[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 96)     376416      ['concatenate_20[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 7, 7, 176)   704         ['conv2d_101[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 7, 7, 160)   640         ['conv2d_102[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 7, 7, 160)   640         ['conv2d_103[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 7, 7, 96)    384         ['conv2d_104[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 7, 7, 96)    384         ['conv2d_105[0][0]']
#  ormalization)
#
#  max_pooling2d_21 (MaxPooling2D  (None, 7, 7, 784)   0           ['concatenate_20[0][0]']
#  )
#
#  activation_85 (Activation)     (None, 7, 7, 176)    0           ['batch_normalization_84[0][0]']
#
#  activation_86 (Activation)     (None, 7, 7, 160)    0           ['batch_normalization_85[0][0]']
#
#  activation_87 (Activation)     (None, 7, 7, 160)    0           ['batch_normalization_86[0][0]']
#
#  activation_88 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_87[0][0]']
#
#  activation_89 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_88[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 96)     75360       ['max_pooling2d_21[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 7, 7, 784)    0           ['activation_85[0][0]',
#                                                                   'activation_86[0][0]',
#                                                                   'activation_87[0][0]',
#                                                                   'activation_88[0][0]',
#                                                                   'activation_89[0][0]',
#                                                                   'conv2d_106[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 784)   0           ['concatenate_21[0][0]']
#  oling2D)
#
#  dropout_1 (Dropout)            (None, 1, 1, 784)    0           ['average_pooling2d_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 784)          0           ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 10)           7850        ['flatten_1[0][0]']
#
#  activation_90 (Activation)     (None, 10)           0           ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 4,736,602
# Trainable params: 4,729,658
# Non-trainable params: 6,944
# __________________________________________________________________________________________________

# %%
score=model.evaluate(testX,testY)
print('Test Score=',score[0])
print('Test Accuracy=',score[1])
# Out:
# 313/313 [==============================] - 9s 28ms/step - loss: 0.4556 - accuracy: 0.8480
# Test Score= 0.45556288957595825
# Test Accuracy= 0.8479999899864197
